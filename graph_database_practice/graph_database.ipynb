# %%
import pandas as pd
import numpy as np

result=pd.Series([1,3,5])
result
# Out:
# 0    1
# 1    3
# 2    5
# dtype: int64

# %%
result=pd.Series([1,3,5,np.nan,6,8])
result
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
s= pd.Series(np.random.randn(5))
s
# Out:
# 0    0.305778
# 1    0.254607
# 2    0.263171
# 3    0.733613
# 4    0.869339
# dtype: float64

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s=pd.Series(np.random.randn(11),index=['a','b','c','d','e','f','g','h','i','j','k'])
s
# Out:
# a    0.763986
# b   -1.233439
# c   -0.245074
# d    0.146987
# e   -0.761680
# f    1.850016
# g    0.447446
# h    2.017875
# i   -0.439650
# j   -1.457522
# k   -0.793074
# dtype: float64

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k'], dtype='object')

# %% [markdown]
# From dict:- series can be instantiated

# %%
dictvar={"a":2,"b":3,"c":4}
d=pd.Series(dictvar)
d
# Out:
# a    2
# b    3
# c    4
# dtype: int64

# %%
d.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
res1= pd.Series(5., index=['a', 'b', 'c', 'd', 'e']) # value is same
res1
# Out:
# a    5.0
# b    5.0
# c    5.0
# d    5.0
# e    5.0
# dtype: float64

# %%
d = {'one': pd.Series([1., 2., 3.], index=['a', 'b', 'c']),
     'two': pd.Series([1., 2., 3., 4.], index=['a', 'b', 'c', 'd'])}
df=pd.DataFrame(d)
df
# Out:
#    one  two
# a  1.0  1.0
# b  2.0  2.0
# c  3.0  3.0
# d  NaN  4.0

# %%
dictvar={"a":2,"b":3,"c":4}
df1=pd.DataFrame(dictvar, index=['d', 'b', 'a'])
df1
# Out:
#    a  b  c
# d  2  3  4
# b  2  3  4
# a  2  3  4

# %%
df1.index
# Out:
# Index(['d', 'b', 'a'], dtype='object')

# %%
data = np.zeros((2, ), dtype=[('A', 'i4'), ('B', 'f4'), ('C', 'a10')])
data[:]
# Out:
# array([(0, 0., b''), (0, 0., b'')],
#       dtype=[('A', '<i4'), ('B', '<f4'), ('C', 'S10')])

# %%
r1=pd.DataFrame(data)
r1
# Out:
#    A    B    C
# 0  0  0.0  b''
# 1  0  0.0  b''

# %%
data2 = [{'a': 1, 'y': 2}, {'a': 5, 'b': 10, 'c': 20}]
df2=pd.DataFrame(data2)
df2
# Out:
#    a     b     c    y
# 0  1   NaN   NaN  2.0
# 1  5  10.0  20.0  NaN

# %%
r3=pd.DataFrame(data2, index=['first', 'second'])
r4=pd.DataFrame(r3)
r4
# Out:
#         a     b     c    y
# first   1   NaN   NaN  2.0
# second  5  10.0  20.0  NaN

# %%
r5=pd.DataFrame(data2, columns=['a', 'b'])
r5
# Out:
#    a     b
# 0  1   NaN
# 1  5  10.0

# %%
df1
# Out:
#    a  b  c
# d  2  3  4
# b  2  3  4
# a  2  3  4

# %%
df2
# Out:
#    a     b     c    y
# 0  1   NaN   NaN  2.0
# 1  5  10.0  20.0  NaN

# %%
df1col=list(df1.columns)

# %%
df2col=list(df2.columns)

# %%
match_col=[]
for col in df1col:
    if col in df2col:
        print(col)
        match_col.append(col)
# Out:
# a
# b
# c

# %%
match_col
# Out:
# ['a', 'b', 'c']

# %%
import pandas as pd
excel_file="movies.xls"
moviesdf1=pd.read_excel(excel_file,sheetname=0)
moviesdf1
# Out:
#                                                   Title  Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916
# 1                       Over the Hill to the Poorhouse   1920
# 2                                       The Big Parade   1925
# 3                                           Metropolis   1927
# 4                                        Pandora's Box   1929
# 5                                  The Broadway Melody   1929
# 6                                        Hell's Angels   1930
# 7                                   A Farewell to Arms   1932
# 8                                          42nd Street   1933
# 9                                   She Done Him Wrong   1933
# 10                               It Happened One Night   1934
# 11                                             Top Hat   1935
# 12                                        Modern Times   1936
# 13                     The Charge of the Light Brigade   1936
# ...

# %%
excel_file="movies.xls"
moviesdf2=pd.read_excel(excel_file,sheetname=1)
moviesdf2
# Out:
#                                      Title  Year  \
# 0                          102 Dalmatians   2000
# 1                                 28 Days   2000
# 2                               3 Strikes   2000
# 3                                Aberdeen   2000
# 4                   All the Pretty Horses   2000
# 5                           Almost Famous   2000
# 6                         American Psycho   2000
# 7                           Amores Perros   2000
# 8                    An Everlasting Piece   2000
# 9                                 Anatomy   2000
# 10                     Autumn in New York   2000
# 11                             Bamboozled   2000
# 12                      Battlefield Earth   2000
# 13                              Bedazzled   2000
# 14                           Best in Show   2000
# 15                      Big Momma's House   2000
# 16                           Billy Elliot   2000
# 17                        Bless the Child   2000
# ...

# %%
excel_file="movies.xls"
moviesdf3=pd.read_excel(excel_file,sheetname=2)
moviesdf3
# Out:
#                                           Title    Year  \
# 0                                    127 Hours   2010.0
# 1                                  3 Backyards   2010.0
# 2                                            3   2010.0
# 3                    8: The Mormon Proposition   2010.0
# 4          A Turtle's Tale: Sammy's Adventures   2010.0
# 5                          Alice in Wonderland   2010.0
# 6                          Alice in Wonderland   2010.0
# 7                              All Good Things   2010.0
# 8                              Alpha and Omega   2010.0
# 9                                        Amigo   2010.0
# 10                            Anderson's Cross   2010.0
# 11                              Animals United   2010.0
# 12                                Another Year   2010.0
# 13                            Barney's Version   2010.0
# 14                                Barry Munday   2010.0
# 15                                   Beginners   2010.0
# ...

# %%
moviesdf1.columns
# Out:
# Index(['Title', 'Year', 'Genres', 'Language', 'Country', 'Content Rating',
#        'Duration', 'Aspect Ratio', 'Budget', 'Gross Earnings', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3', 'Facebook Likes - Director',
#        'Facebook Likes - Actor 1', 'Facebook Likes - Actor 2',
#        'Facebook Likes - Actor 3', 'Facebook Likes - cast Total',
#        'Facebook likes - Movie', 'Facenumber in posters', 'User Votes',
#        'Reviews by Users', 'Reviews by Crtiics', 'IMDB Score'],
#       dtype='object')

# %%
moviesdf2.columns
# Out:
# Index(['Title', 'Year', 'Genres', 'Language', 'Country', 'Content Rating',
#        'Duration', 'Aspect Ratio', 'Budget', 'Gross Earnings', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3', 'Facebook Likes - Director',
#        'Facebook Likes - Actor 1', 'Facebook Likes - Actor 2',
#        'Facebook Likes - Actor 3', 'Facebook Likes - cast Total',
#        'Facebook likes - Movie', 'Facenumber in posters', 'User Votes',
#        'Reviews by Users', 'Reviews by Crtiics', 'IMDB Score'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
df2.columns
# Out:
# Index(['a', 'b', 'c', 'y'], dtype='object')
